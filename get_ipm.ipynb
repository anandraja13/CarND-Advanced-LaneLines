# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import glob
# %matplotlib inline

# %% [markdown]
# # Read and display image

# %%
img = cv2.imread('test_images/straight_lines1.jpg')
h,w = img.shape[:2]
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Define source and destination points

# %%
src = np.float32([(536,488),
                  (751,488),
                  (241,687),
                  (1071,687)])
dst = np.float32([(450,0),
                  (1280-450,0),
                  (450,720),
                  (1280-450,720)])

# %% [markdown]
# # Compute transforms and warp image

# %%
M    = cv2.getPerspectiveTransform(src, dst)
Minv = cv2.getPerspectiveTransform(dst, src)
warped = cv2.warpPerspective(img, M, (w,h), flags=cv2.INTER_LINEAR)

# %% [markdown]
# # Show IPM

# %%
plt.imshow(cv2.cvtColor(warped,cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Try this on test images

# %%
dir_name = 'test_images/'
items = images = glob.glob('./test_images/*.jpg')

plt.figure(1)
n = 241
for image_name in items:
    
    # Read image
    img = cv2.imread(image_name)
    
    # Warp image
    warped = cv2.warpPerspective(img, M, (w,h), flags=cv2.INTER_LINEAR)
    
    # Plot warped image
    plt.subplot(n)
    plt.imshow(cv2.cvtColor(warped, cv2.COLOR_BGR2RGB))
    
    n = n + 1
# Out:
# ['./test_images/test6.jpg', './test_images/test5.jpg', './test_images/test4.jpg', './test_images/test1.jpg', './test_images/test3.jpg', './test_images/test2.jpg', './test_images/straight_lines2.jpg', './test_images/straight_lines1.jpg']
